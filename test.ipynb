# %%
import pandas as pd

# %%
col_names = ['Geographic name', 'Name', 'Estimate Total', 'Margin of Error Total', 'Estimate Total: White', 'Margin of Error: White', 'Estimate Total: Black',
            'Margin of Error: Black', 'Estimate Total: Native', 'Margin of Error: Native', 'Estimate Total: Hawaiian/PI', 'Margin of Error: Hawaiian/PI',
            'Estimate Total: Other', 'Margin of Error: Other', 'Estimate Total: 2+', 'Margin of Error: 2+',]
county_race = pd.read_csv("county_racial.csv", names = col_names, usecols = list(range(1,17)))
county_race = county_race.iloc[2:]
county_race.head()
# Out:
#            Geographic name    Name Estimate Total Margin of Error Total  \
# 2  Baldwin County, Alabama  223234          *****                190912
# 3  Calhoun County, Alabama  113605          *****                 82323
# 4  Cullman County, Alabama     NaN            NaN                   NaN
# 5   DeKalb County, Alabama   71513          *****                 59305
# 6   Elmore County, Alabama   81209          *****                 61634
#
#   Estimate Total: White Margin of Error: White Estimate Total: Black  \
# 2                  2259                  18338                  1834
# 3                  1330                  25226                  1306
# 4                   NaN                    NaN                   NaN
# 5                  1375                    688                   434
# 6                   311                  17768                   410
#
#   Margin of Error: Black Estimate Total: Native Margin of Error: Native  \
# ...

# %%
county_covid_deaths = pd.read_csv("Provisional_COVID-19_Death_Counts_by_County_and_Race.csv")
county_covid_deaths.head()
# Out:
#    Data as of  Start Date    End Date State             County Name  \
# 0  03/24/2021  01/01/2020  03/20/2021    AK  Anchorage Municipality
# 1  03/24/2021  01/01/2020  03/20/2021    AK  Anchorage Municipality
# 2  03/24/2021  01/01/2020  03/20/2021    AK  Anchorage Municipality
# 3  03/24/2021  01/01/2020  03/20/2021    AL          Baldwin County
# 4  03/24/2021  01/01/2020  03/20/2021    AL          Baldwin County
#
#    Urban Rural Code  FIPS State  FIPS County  FIPS Code  \
# 0                 3           2           20       2020
# 1                 3           2           20       2020
# 2                 3           2           20       2020
# 3                 4           1            3       1003
# 4                 4           1            3       1003
#
#                               Indicator  ...  COVID-19 Deaths  \
# 0  Distribution of all-cause deaths (%)  ...              185
# 1   Distribution of COVID-19 deaths (%)  ...              185
# ...
